# %% [markdown]
# <a href="https://colab.research.google.com/github/KIRANVVIT/CODE-FOBE-PROBLEM-STATEMENTS/blob/main/week10_practice_kiran.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Week 10, Data Handling and Analysis Practising**

# %%
#read csvfile into a data frame
import pandas as pd
data_csv = pd.read_csv('ecommerce_sales.csv')
print(data_csv)
# Out:
#      Order_Date     Product     Category  Quantity  Price_Per_Unit  Shipping_Fee  Total_Sales
# 0    12/17/2024  Headphones  Electronics       6.0          149.62         48.55       946.27
# 1    12/16/2024      Laptop  Electronics      16.0          203.15         38.78      3289.18
# 2     12/5/2024    Lipstick       Beauty      11.0          162.08         38.19      1821.07
# 3    12/18/2024       Dress     Clothing       6.0          443.55          3.06      2664.36
# 4     12/2/2024     Fantasy        Books      10.0          123.24         38.29      1270.69
# ..          ...         ...          ...       ...             ...           ...          ...
# 195   12/9/2024  Smartphone  Electronics       3.0          482.80         46.79      1495.19
# 196  12/26/2024  Headphones  Electronics      20.0          284.58          9.36      5700.96
# 197  12/30/2024      Tablet  Electronics       5.0          365.30         46.79      1873.29
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)

# Display the DataFrame again to see the effect
display(data_csv)
# Out:
#      Order_Date     Product     Category  Quantity  Price_Per_Unit  Shipping_Fee  Total_Sales
# 0    12/17/2024  Headphones  Electronics       6.0          149.62         48.55       946.27
# 1    12/16/2024      Laptop  Electronics      16.0          203.15         38.78      3289.18
# 2     12/5/2024    Lipstick       Beauty      11.0          162.08         38.19      1821.07
# 3    12/18/2024       Dress     Clothing       6.0          443.55          3.06      2664.36
# 4     12/2/2024     Fantasy        Books      10.0          123.24         38.29      1270.69
# ..          ...         ...          ...       ...             ...           ...          ...
# 195   12/9/2024  Smartphone  Electronics       3.0          482.80         46.79      1495.19
# 196  12/26/2024  Headphones  Electronics      20.0          284.58          9.36      5700.96
# 197  12/30/2024      Tablet  Electronics       5.0          365.30         46.79      1873.29
# ...

# %%
print(data_csv)
# Out:
#      Order_Date     Product     Category  Quantity  Price_Per_Unit  Shipping_Fee  Total_Sales
# 0    12/17/2024  Headphones  Electronics       6.0          149.62         48.55       946.27
# 1    12/16/2024      Laptop  Electronics      16.0          203.15         38.78      3289.18
# 2     12/5/2024    Lipstick       Beauty      11.0          162.08         38.19      1821.07
# 3    12/18/2024       Dress     Clothing       6.0          443.55          3.06      2664.36
# 4     12/2/2024     Fantasy        Books      10.0          123.24         38.29      1270.69
# ..          ...         ...          ...       ...             ...           ...          ...
# 195   12/9/2024  Smartphone  Electronics       3.0          482.80         46.79      1495.19
# 196  12/26/2024  Headphones  Electronics      20.0          284.58          9.36      5700.96
# 197  12/30/2024      Tablet  Electronics       5.0          365.30         46.79      1873.29
# ...

# %%
#reading excel file
import pandas as pd
data_excel = pd.read_excel('ecommerce_sales.xlsx')
print(data_excel)
# Out:
#     Order_Date     Product        Category  Quantity  Price_Per_Unit  Shipping_Fee  Total_Sales
# 0   2024-12-15  Smartphone     Electronics        11          300.51         27.48      3333.09
# 1   2024-12-29  Headphones     Electronics        20           56.37          5.60      1133.00
# 2   2024-12-04   Biography           Books         8          132.37         20.69      1079.65
# 3   2024-12-11       Jeans        Clothing         8          173.52         40.36      1428.52
# 4   2024-12-18      Jacket        Clothing        17          129.81         43.74      2250.51
# ..         ...         ...             ...       ...             ...           ...          ...
# 195 2024-12-13     Mascara          Beauty         8          321.27         46.91      2617.07
# 196 2024-12-05     Mascara          Beauty        12          484.76         11.42      5828.54
# 197 2024-12-23     Toaster  Home & Kitchen         8          100.76          4.81       810.89
# ...

# %%
from google.colab import drive

# Mount the drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/MyDrive/CODEFOBE/DATASETS'
# Out:
# ecommerce_sales.csv  ecommerce_sales.xlsx

# %%
import pandas as pd
data_csv = pd.read_csv('/content/drive/MyDrive/CODEFOBE/DATASETS/ecommerce_sales.csv')
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)

print(data_csv)
# Out:
#      Order_Date     Product     Category  Quantity  Price_Per_Unit  Shipping_Fee  Total_Sales
# 0    12/17/2024  Headphones  Electronics       6.0          149.62         48.55       946.27
# 1    12/16/2024      Laptop  Electronics      16.0          203.15         38.78      3289.18
# 2     12/5/2024    Lipstick       Beauty      11.0          162.08         38.19      1821.07
# 3    12/18/2024       Dress     Clothing       6.0          443.55          3.06      2664.36
# 4     12/2/2024     Fantasy        Books      10.0          123.24         38.29      1270.69
# ..          ...         ...          ...       ...             ...           ...          ...
# 195   12/9/2024  Smartphone  Electronics       3.0          482.80         46.79      1495.19
# 196  12/26/2024  Headphones  Electronics      20.0          284.58          9.36      5700.96
# 197  12/30/2024      Tablet  Electronics       5.0          365.30         46.79      1873.29
# ...

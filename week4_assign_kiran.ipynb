# %% [markdown]
# <a href="https://colab.research.google.com/github/KIRANVVIT/CODE-FOBE-PROBLEM-STATEMENTS/blob/main/week4_assign_kiran.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Week 4 Python Collections: Lists, Tuples, Sets, and Dictionaries.**

# %% [markdown]
# # **Week 4, Session 2, sunday, 5 April 2026**
# **Week 4 Session 2 Coding Problem statement .ipynb**

# %% [markdown]
# 1. **Problem**: Find Common Ingredients in Two Recipes
# Imagine you are comparing the ingredients for two different recipes. Each recipe has its own set of ingredients, and you want to see which ingredients are common to both recipes. This will help you identify the shared items needed for both dishes.
#
# In this problem, you need to:
#
# Create two sets, where each set contains the ingredients for one recipe.
# Find the ingredients that appear in both sets.
# Print the common ingredients so you can see which items are shared between the two recipes.
# Key Points:
#
# Sets are collections that automatically remove duplicates, making them useful for comparing unique items.
# Using the & operator with two sets finds the intersection, or common elements, between the sets.
# Sample Output: Common Ingredients: {'sugar', 'eggs'}

# %%
#1.find common ingredients in two recipes
#2 sets of ingredients
item_set1 = {"sugar", "eggs", "flour", "milk"}
item_set2 = {"butter", "butter", "sugar", "eggs"}
#find common ingredients
common_ingredients = item_set1 & item_set2
#print common ingredients
print("Common Ingredients:", common_ingredients)
# Out:
# Common Ingredients: {'sugar', 'eggs'}

# %% [markdown]
# 2. **Problem**: Add a New City to Visited Cities
# Imagine you are keeping track of the cities you’ve visited in a set. A set is useful here because it automatically keeps each city unique, so if you accidentally try to add a city twice, it won’t be duplicated. Now, you want to add a new city, "Paris," to this set of visited cities. This will help you update your list with the latest place you’ve traveled to.
#
# In this problem, you need to:
#
# Start with a set of cities that you’ve already visited.
# Add the city "Paris" to the set.
# Print the updated set to see the complete list of unique cities you’ve visited.
# Key Points:
#
# Sets only allow unique items, so each city will appear only once.
# The .add() method is used to add an item to a set.
# Sample Output: Visited Cities: {'London', 'Berlin', 'Tokyo', 'Paris'}

# %%
#2. add a new city to visited cities
#set of cities
visited_cities = {"London", "Berlin", "Tokyo"}
#add paris to the set
visited_cities.add("Paris")
#printing the cities list
print("Visited Cities:", visited_cities)
# Out:
# Visited Cities: {'Berlin', 'Paris', 'Tokyo', 'London'}

# %% [markdown]
# 3. **Problem**: Remove an Outdated Item from Inventory
# Imagine you are managing a store inventory, which is represented as a set of items. A set is useful here because it automatically keeps each item unique, so there won’t be any duplicates in the inventory list. Now, suppose one of the items in the inventory, "iPhone 8", is outdated, and you want to remove it from the set. This will help keep your inventory list updated by removing products you no longer sell.
#
# In this problem, you need to:
#
# Start with a set of items in the store inventory.
# Remove "iPhone 8" from the set.
# Print the updated set to see the remaining items in the inventory.
# Key Points:
#
# Sets only contain unique items, so each product appears only once.
# The .remove() method is used to remove an item from a set.
# Sample Output: Updated Inventory: {'iPhone 12', 'Samsung Galaxy S21', 'MacBook Air', 'iPad Pro'}

# %%
#3. remove an outdated item from inventory
#set of inventory items
inventory_items = {"iPhone 12", "Samsung Galaxy S21", "MacBook Air", "iPad Pro", "iPhone 8"}
#removing an item
inventory_items.remove("iPhone 8")
#printing the updated list
print("Updated Inventory:", inventory_items)
# Out:
# Updated Inventory: {'iPad Pro', 'iPhone 12', 'Samsung Galaxy S21', 'MacBook Air'}

# %% [markdown]
# 4. **Problem**: Get All Keys in a Dictionary
# Imagine you have a dictionary where each student's name is a key, and their grade is the value. Now, you want to retrieve a list of all student names from this dictionary. This could be useful if you need to see a list of all students without looking at their grades.
#
# In this problem, you need to:
#
# Start with a dictionary where each key is a student’s name and each value is that student’s grade.
# Retrieve all the keys (student names) from this dictionary.
# Print the list of student names.
# Key Points:
#
# A dictionary in Python contains keys and values, where each key is associated with a specific value.
# The .keys() method returns all the keys in the dictionary, which you can then convert into a list if needed.
# Sample Output: Student Names: ['Alice', 'Bob', 'Charlie']

# %%
#4. get all keys in a dictionary
#dictionary of students' names as keys and grades as values
student_list = {
    "Alice": 85,
    "Bob": 78,
    "Charlie": 92
    }
#retrieve all keys from dict
student_names = list(student_list.keys())
#printing the list of student names
print("Student Names:", student_names)
# Out:
# Student Names: ['Alice', 'Bob', 'Charlie']

# %% [markdown]
# 5. **Problem**: Find All Items with Prices Above ₹100
# Imagine you have a dictionary where each fruits in a store is listed as a key, and its price in rupees is the value. You want to find and display only the Fruits that cost more than ₹100. This can help you focus on the more expensive items and filter out the lower-priced ones.
#
# In this problem, you need to:
#
# Initialize a new empty dictionary called above_hundred_rupees to store fruit priced above ₹100.
# Use a for loop to go through each item and its price in the original prices dictionary.
# Use an if condition to check if the price of each item is greater than ₹100.
# If the condition is met, add that item and its price to the above_hundred_rupees dictionary.
# Print the new dictionary that contains only the items priced above ₹100.
# Key Points:
#
# A dictionary stores key-value pairs, where each key is associated with a specific value.
# Use a for loop with the .items() method to access both the keys and values.
# The if condition allows filtering of items based on their prices.
# Sample Output: Items above ₹100: {'apple': 120, 'cherry': 250, 'dates': 150}

# %%
#5. find all items with prices above 100
#dict of fruites and their prices
fruits_prices = {
    "apple": 120,
    "banana": 6,
    "cherry": 250,
    "dates": 150
}
#empty dict to store fruits above 100
above_hundred_rupees = {}
#loop through the dict
for fruit, price in fruits_prices.items():
    if price > 100:
        above_hundred_rupees[fruit] = price

#printing the dict
print("Items above ₹100:", above_hundred_rupees)
# Out:
# Items above ₹100: {'apple': 120, 'cherry': 250, 'dates': 150}

# %% [markdown]
# 6. **Problem**: Track Unique Attendees Across Multiple Events
# Imagine you are organizing three different events, and you have lists of people who attended each one. Some people may have attended more than one event, and you want to find out how many unique individuals attended across all three events. This will give you a list of everyone who attended at least one of the events, without counting anyone more than once.
#
# In this problem, you need to:
#
# Start with three sets where each set contains the names of attendees for a specific event.
# Combine these sets to create one final set of unique attendees across all events.
# Print the resulting set to see the total list of unique individuals.
# Key Points:
#
# Sets automatically remove duplicates, making them ideal for tracking unique items.
# The | operator allows you to combine multiple sets into one, including only unique values from each set.
# Sample Output: Unique Attendees: {'Alice', 'Bob', 'Charlie', 'David', 'Ella', 'Frank'}

# %%
#6. track unique attendees across multiple events
# 3 sets of names of attendees in 3 events
event1 = {"Alice", "Bob", "Charlie", "David"}
event2 = {"Bob", "David", "Ella", "Frank"}
event3 = {"Charlie", "David", "Grace", "Hannah"}
#combine 3 sets to find unique of all the three (combine = union,|)
unique_attendees = event1 | event2 | event3
#printing the unique attendees
print("Unique Attendees:", unique_attendees)
# Out:
# Unique Attendees: {'David', 'Hannah', 'Charlie', 'Frank', 'Ella', 'Bob', 'Alice', 'Grace'}

# %% [markdown]
# 7. **Problem**: Identify Employees Who Attended All Mandatory Trainings
# Imagine that a company has organized three mandatory training sessions, and employees are required to attend all three. You have separate sets of employees who attended each training. Your goal is to find out which employees attended all three trainings. This will help the company ensure that everyone who needed to attend all the mandatory trainings actually did so.
#
# In this problem, you need to:
#
# Start with three sets where each set contains the names of employees who attended a specific training.
# Find the intersection of these sets, which includes only those employees who are present in all three sets.
# Print the final set to see the list of employees who attended all mandatory trainings.
# Key Points:
#
# Sets are useful for comparing groups and identifying common elements, as they automatically remove duplicates.
# The & operator can be used with sets to find the intersection, which shows only the elements present in all sets.
# Sample Output: Employees who attended all trainings: {'Alice', 'Bob'}

# %%
#7. identify employees who attended all mandatory trainings
#3 sets of names of employees who attended 3 events
event1 = {"Alice", "Bob", "Charlie"}
event2 = {"Bob", "David", "Alice"}
event3 = {"Charlie", "Eve", "Alice"}
#find the intersection m & operator for intersection
allevents_attendees = event1 & event2 & event3
#printing the final set
print("Employees who attended all trainings:", allevents_attendees)
# Out:
# Employees who attended all trainings: {'Alice'}

# %% [markdown]
# 8. **Problem**: Calculate Inventory Worth
# Imagine you are managing a store’s inventory, and you have a dictionary where each item is listed with its price in rupees. Each key in the dictionary is the name of an item (like "Laptop" or "Tablet"), and each value is the price of that item in rupees. You want to calculate the total worth of all items in the inventory. This means you need to add up the prices of each item to find the total value of the store’s inventory.
#
# In this problem, you need to:
#
# Start with a dictionary where each key is an item name and each value is the item’s price in rupees.
# Calculate the sum of all the values (prices) in the dictionary.
# Print the total worth of the inventory.
# Key Points:
#
# A dictionary in Python stores key-value pairs, where each key is associated with a specific value.
# The .values() method allows you to access just the values (prices) in the dictionary.
# The sum() function can then add up these values to get the total worth.
# Sample Output: Total Inventory Worth (in ₹): 95000

# %%
#8.calculate inventory worth, dict
#dict of item as key and price as value
item_prices = {
    "Laptop": 50000,
    "Tablet": 30000,
    "Phone": 20000,
    "Monitor": 10000
}
#adding up all the prices
total_worth = sum(item_prices.values())
#printing the total worth
print("Total Inventory Worth (in ₹):", total_worth)
# Out:
# Total Inventory Worth (in ₹): 110000

# %% [markdown]
# 9. **Problem**: Register and Check Club Members
# Imagine you are managing a club, and you have a set of names representing current club members. When a new person wants to join, you need to check if their name is already in the club members' list. If they are already a member, you don’t need to add them again. However, if they aren’t a member yet, you’ll add their name to the set.
#
# In this problem, you need to:
#
# Define a set of existing club members.
# Prompt the user to enter a name.
# Use an if statement to check if the name is in the set.
# If the name is in the set, print a message saying they’re already a member.
# If the name is not in the set, add it and print a message confirming the addition.
# Print the updated set of club members.
# Key Points:
# Sets automatically keep only unique items, so if you try to add a member who’s already in the set, it won’t create duplicates.
# Using if and else statements allows you to conditionally check if a name is in the set and respond accordingly.
# Sample Output:
#
# Enter the name to check membership: David
#
# David has been added to the club members.
#
# Current Members: {'Alice', 'Charlie', 'Bob', 'David'}

# %%
#9. register and check club members
# a set of existing club members
club_members = {"Alice", "Charlie", "Bob"}
#prompt the user to enter name
name = input("Enter the name to check membership: ")
#check if name is in the set
if name in club_members:
    print(name, "is already a member.")
else:
    club_members.add(name)
    print(name, "has been added to the club members.")
#print the updated set
print("Current Members:", club_members)
# Out:
# Enter the name to check membership: David
# David has been added to the club members.
# Current Members: {'Charlie', 'David', 'Bob', 'Alice'}

# %% [markdown]
# 10. **Problem**: Add Multiple Products to a Store Inventory
# Imagine you are managing a store’s inventory, which is represented by a set of products currently available. You want to add new products to this inventory as they arrive. You’ll keep adding products one by one until you’re done, and then display the updated inventory.
#
# In this problem, you need to:
#
# Start with an existing set of products in the inventory.
# Prompt the user to enter the name of a new product to add to the inventory.
# If the user types the product name, add it to the inventory set.
# Repeat this process until the user types "done," indicating they’ve finished entering new products.
# Print the updated inventory set to show all the products now available.
# Key Points:
#
# Sets automatically store unique items, so any product entered more than once will only appear once in the inventory.
# Using a while loop allows continuous input until the user decides to stop by typing "done."
# The break statement is used to exit the loop when the user indicates they’re finished.
# Sample Output:
# Enter a product to add to inventory (type 'done' to stop): grapes
#
# Enter a product to add to inventory (type 'done' to stop): mango
#
# Enter a product to add to inventory (type 'done' to stop): done
#
# Updated Inventory: {'apple', 'banana', 'orange', 'grapes', 'mango'}

# %%
#10. add multiple products t a store inventory
#set of products in inventory
product_inventory = {"apple", "banana", "orange"}
#enter name of new product to add to inventory
while True:
    new_product = input("Enter a product to add to inventory (type 'done' to stop): ")
    if new_product == "done":
        break
    product_inventory.add(new_product)
#print the updated inventory
print("Updated Inventory:", product_inventory)
# Out:
# Enter a product to add to inventory (type 'done' to stop): grapes
# Enter a product to add to inventory (type 'done' to stop): mango
# Enter a product to add to inventory (type 'done' to stop): done
# Updated Inventory: {'grapes', 'mango', 'apple', 'banana', 'orange'}

# %% [markdown]
# 11.**Problem**: Manage Restaurant Reservations
# Imagine you are managing reservations for a restaurant, where each table has a specific reservation. You have a dictionary where each key is a table name (e.g., "Table1") and each value is the name of the guest who reserved it. You want to give the user two options: they can either add a new reservation or remove an existing reservation.
#
# In this problem, you need to:
#
# Start with a dictionary that represents current reservations.
#
# Prompt the user to choose an action:
#
# "add" to add a reservation.
#
# "remove" to remove an existing reservation.
#
# -- If the user chooses to add:
#
# Ask them to enter the table name and guest name.
# -- Check if the table already has a reservation:
#
# If it does, inform the user that the table is already reserved (e.g., "Table1 already has a reservation for Alice").
# If it does not, update the dictionary by adding the guest name for the specified table and confirm the addition.
# --If the user chooses to remove:
#
# Ask them to enter the table name of the reservation they want to remove. Check if the table has an existing reservation:
# If it does, delete it and confirm the removal (e.g., "Reservation for Table1 removed").
# If it does not, inform the user that no reservation was found for the specified table.
# Finally, display the current list of reservations to show the updated reservations.
# Key Points:
#
# Dictionaries are ideal for managing reservations as they allow you to associate each table with a specific guest’s name.
# if and elif statements enable handling different actions based on the user’s input.
# The in keyword checks if a specific table exists in the dictionary, while the del statement removes a key-value pair if the table is found.
# Sample Output:
#
# Adding a reservation (table already reserved):
#
# Enter 'add' to add a reservation or 'remove' to remove a reservation: add
#
# Enter table name: Table1
#
# Table1 already has a reservation for Alice.
#
# Current Reservations: {'Table1': 'Alice', 'Table2': 'Bob'}
#
# Removing a reservation (table not found):
#
# Enter 'add' to add a reservation or 'remove' to remove a reservation: remove
#
# Enter table name to remove reservation: Table3
#
# No reservation found for Table3.
#
# Current Reservations: {'Table1': 'Alice', 'Table2': 'Bob'}

# %%
#11. manage restaurant reservations
#dict of current reservations, table as key, guest name as value
restaurant_reservations = {
    "Table1": "Alice",
    "Table2": "Bob",
    "Table3": "Charlie"
}
#prompt to select add or remove reservation
action = input("Enter 'add' to add a reservation or 'remove' to remove a reservation: ")
# checking the action
if action == "add":
    table_name = input("Enter table name: ")

    if table_name in restaurant_reservations:
        print(table_name, "already has a reservation for", restaurant_reservations[table_name])
    else:
        guest_name = input("Enter guest name: ")
        restaurant_reservations[table_name] = guest_name
else:
    table_name = input("Enter table name to remove reservation: ")
    if table_name in restaurant_reservations:
        del restaurant_reservations[table_name]
        print("Reservation for", table_name, "removed")
    else:
        print("No reservation found for", table_name)
#current updated reservation list
print("Current Reservations:", restaurant_reservations.items())
# Out:
# Enter 'add' to add a reservation or 'remove' to remove a reservation: remove
# Enter table name to remove reservation: Table4
# No reservation found for Table4
# Current Reservations: dict_items([('Table1', 'Alice'), ('Table2', 'Bob'), ('Table3', 'Charlie')])

# %% [markdown]
# 12. **Problem**: Update Product Prices
# Imagine you are managing a store’s inventory, which includes a dictionary of products and their prices. Each key in the dictionary is the name of a product (like "apple" or "banana"), and each value is its price. You want to give the user an option to update the price of a specific product. If the product is in the inventory, you’ll allow them to enter a new price to replace the old one. If the product isn’t in the inventory, you’ll let the user know that the product wasn’t found.
#
# In this problem, you need to:
#
# Start with a dictionary that contains the names and prices of products.
# Prompt the user to enter the name of the product they want to update.
# Use an if statement to check if the product is in the dictionary.
# If it is, ask the user for the new price, update the dictionary with this new price, and confirm the update.
# If it isn’t, inform the user that the product is not in the inventory.
# Display the updated dictionary to show the current prices of all products.
# Key Points:
#
# Dictionaries are ideal for pairing items with specific information, like products with prices.
# Using if and else statements allows you to handle cases where the product is in the dictionary or not.
# Directly updating the value for a key in a dictionary will replace the existing value with the new one.
# Sample Output:
#
# Enter the product to update price: apple
#
# Enter the new price for apple: 60
#
# Price for apple updated to 60.
#
# Updated Prices: {'apple': 60, 'banana': 30, 'cherry': 100}
#
# Or, if the product is not in the inventory:
#
# Enter the product to update price: grapes
#
# grapes not found in inventory.
#
# Updated Prices: {'apple': 50, 'banana': 30, 'cherry': 100}

# %%
#12. Update product prices
#dict of products and prices in a store
product_prices = {
    "apple": 50,
    "banana": 30,
    "cherry": 100
}
#enter the name of the product to be updated
product_to_update = input("Enter the product to update price: ")
#check if product is in the dict
if product_to_update in product_prices:
    new_price = int(input("Enter the new price for " + product_to_update + ": "))
    product_prices[product_to_update] = new_price
    print("Price for", product_to_update, "updated to", new_price)
else:
    print(product_to_update, "not found in inventory.")
#print the updated dict
print("Updated Prices:", product_prices.items())
# Out:
# Enter the product to update price: grapes
# grapes not found in inventory.
# Updated Prices: dict_items([('apple', 50), ('banana', 30), ('cherry', 100)])

# %% [markdown]
# 13. Problem: Add a New Student Grade
# Imagine you are maintaining a dictionary of student names and their grades. Each key in the dictionary is a student’s name (like "Alice" or "Bob"), and each value is their grade.
#
# Now, you want to add a new student and their grade to this dictionary. You will:
#
# Prompt the user to enter the name of the new student.
# Prompt the user to enter the grade for this student.
# Add this information to the dictionary by setting the student’s name as the key and the grade as the value.
# Finally, display the updated dictionary to show the current list of students and their grades.
# This helps you easily keep track of all students’ grades as new students are added.
# Key Points:
#
# Dictionaries are useful for storing paired data, like student names with their respective grades.
# Directly assigning a value to a new key in a dictionary will add that key-value pair to the dictionary.
# Using input() allows you to prompt the user to provide the name and grade for the new student.
# Sample Output:
#
# Enter the student's name: Charlie
#
# Enter the student's grade: 92
#
# Updated Grades: {'Alice': 85, 'Bob': 78, 'Charlie': 92}

# %%
#13. add a new stucent grade
#dict of student names and their grades
student_list = {
    "Alice": 85,
    "Bob": 78
}
#adding new student to dict
student_name = input("Enter the student's name: ")
student_grade = int(input("Enter the student's grade: "))
student_list[student_name] = student_grade
#print the updated dict
print("Updated Grades:", student_list.items())
# Out:
# Enter the student's name: Charlie
# Enter the student's grade: 92
# Updated Grades: dict_items([('Alice', 85), ('Bob', 78), ('Charlie', 92)])

# %% [markdown]
# 14. **Problem**: Track Event Sign-Ups
# Imagine you are organizing an event, and you want to keep track of who has signed up. You have a set that stores the names of people who have already signed up. When a new person wants to join, you need to check if their name is already in the list of sign-ups.
#
# In this problem, you need to:
#
# Start with a set that includes the names of people who are currently signed up.
# Prompt the user to enter their name to sign up for the event.
# Use an if statement to check if the name is already in the set.
# If the name is already in the set, inform the user that they have already signed up.
# If the name is not in the set, add it to the set and confirm that they have been added.
# Print the updated set to show everyone who has signed up for the event.
# Key Points:
#
# Sets automatically keep only unique items, so adding a name that’s already in the set won’t create duplicates.
# Using if and else statements allows you to handle different cases: whether the user is already signed up or is signing up for the first time.
# Sample Output:
#
# If the user enters a new name:
#
# Enter your name to sign up: Charlie
#
# You have been added to the event.
#
# Current Sign-Ups: {'Alice', 'Bob', 'Charlie'}
#
# if the user enters an existing name:
#
# Enter your name to sign up: Alice
#
# You are already signed up.
#
# Current Sign-Ups: {'Alice', 'Bob'}

# %%
#14. Track Event sign-ups
#set of people who signed up for event
event_signups = {"Alice", "Bob"}
#adding a name to signup
name_to_signup = input("Enter your name to sign up: ")
#checking the name in set
if name_to_signup in event_signups:
    print("You are already signed up.")
else:
    event_signups.add(name_to_signup)
    print("You have been added to the event.")
#print the updated set
print("Current Sign-Ups:", event_signups)
# Out:
# Enter your name to sign up: Alice
# You are already signed up.
# Current Sign-Ups: {'Bob', 'Alice'}

# %% [markdown]
# 15.**Problem**: Manage Friends’ Birthdays
# Imagine you want to keep track of your friends’ birthdays, so you create a dictionary where each friend’s name is the key, and their birthday date is the value.
#
# In this task, you will:
#
# Start with a dictionary that already contains some friends’ birthdays.
# Prompt the user to enter the name of a friend.
# Check if the friend’s name is already in the dictionary:
# If the friend’s name exists in the dictionary, display their current birthday and ask if the user wants to update it:
# If the user chooses to update, prompt them for the new date and update the dictionary with this new date.
# If the user does not want to update, keep the existing date.
# If the friend’s name is not in the dictionary, ask the user to enter the birthday date and add it as a new entry.
# Display the updated dictionary showing all current friends and their birthdays, including any additions or updates.
# Key Points:
#
# Dictionaries are useful here because they allow quick access to each friend’s name and birthday.
# User interaction provides the option to update an existing birthday or retain it.
# Assigning a value to a dictionary key updates it if the key exists or adds it if the key does not exist.
# Sample Output: If you update an existing friend’s birthday:
#
# Enter the friend's name: Alice
#
# Alice is already added with a birthday on 12th Jan.
#
# Would you like to update the birthday? (yes/no): yes
#
# Enter the new birthday date: 10th Jan
#
# Alice's birthday has been updated to 10th Jan.
#
# Updated Birthdays: {'Alice': '10th Jan', 'Bob': '3rd Feb'}
#
# If you add a new friend:
#
# Enter the friend's name: Charlie
#
# Enter the birthday date: 15th Mar
#
# Added Charlie's birthday on 15th Mar.
#
# Updated Birthdays: {'Alice': '12th Jan', 'Bob': '3rd Feb', 'Charlie': '15th Mar'}

# %%
#15. Manage friend's birthdays
#dict of friends birthdays
friends_birthdays = {
    "Alice": "12th Jan",
    "Bob": "3rd Feb"
}
#adding friends to dict
friend_name = input("Enter the friend's name: ")
#checking his/her name in existing dict
if friend_name in friends_birthdays:
    print(friend_name, "is already added with a birthday on", friends_birthdays[friend_name])
    update_birthday = input("Would you like to update the birthday? (yes/no): ")
    if update_birthday == 'yes':
        new_birthday = input("Enter the new birthday date: ")
        friends_birthdays[friend_name] = new_birthday
        print(friend_name, "'s birthday has been updated to", new_birthday)
else:
    birthday_date = input("Enter the birthday date: ")
    friends_birthdays[friend_name] = birthday_date
    print("Added", friend_name, "'s birthday on", birthday_date)
#updated dict is
print("Updated Birthdays:", friends_birthdays.items())
# Out:
# Enter the friend's name: Kiran
# Enter the birthday date: 10th Nov
# Added Kiran 's birthday on 10th Nov
# Updated Birthdays: dict_items([('Alice', '12th Jan'), ('Bob', '3rd Feb'), ('Kiran', '10th Nov')])

# %% [markdown]
# # **Week 4, Session 1, saturday, 4 April 2026**

# %% [markdown]
# 1. Problem: Store and Retrieve Grocery Items
# Imagine you have a list of items that you want to buy from the grocery store, like "Milk," "Bread," "Eggs," "Butter," and "Cheese." Each item is stored in a specific order, and you want to retrieve a specific item based on its position in the list.
#
# In this problem, you need to:
#
# Create a list of grocery items.
# Print the entire list.
# Print the item at index 2 (which is the third item in the list).
# Sample Output:
#
# Grocery List: ['Milk', 'Bread', 'Eggs', 'Butter', 'Cheese']
#
# Third Item: Eggs

# %%
#1.Problem: Store and Retrieve Grocery Items
grocery_list = ["Milk", "Bread", "Eggs", "Butter", "Cheese"]
#printing the entire list
print("Grocery List:", grocery_list)
#printing the item at index 2
print("Third Item:", grocery_list[2])
# Out:
# Grocery List: ['Milk', 'Bread', 'Eggs', 'Butter', 'Cheese']
# Third Item: Eggs

# %% [markdown]
# 2. Problem: Add and Remove Guests for a Party
# Imagine you’re organizing a party and have a list of people who are invited. Initially, you have a few guests on your list: John, Emma, Robert, and Olivia.
#
# Steps:
#
# Start with an initial list of guests.
# Use a method to add "Alice" to the list.
# Use another method to remove "John" from the list.
# Print the final, updated list of guests to confirm the changes
# Sample Output:
#
# Updated Guest List: ['Emma', 'Robert', 'Olivia', 'Alice']

# %%
#2.Problem: Add and Remove Guests for a Party

#initial list of guests
guest_list = ["John", "Emma", "Robert", "Olivia"]
#add Alice to the list
guest_list.append("Alice")
#remove John from the list
guest_list.remove("John")
#printing final updated list
print("Updated Guest List:", guest_list)
# Out:
# Updated Guest List: ['Emma', 'Robert', 'Olivia', 'Alice']

# %% [markdown]
# 3. Problem: Calculate the Total Monthly Expense
# Problem: Calculate the Total Monthly Expense
#
# Imagine you are tracking your spending for a month. You have a list that shows how much you spent in different categories, like rent, groceries, transportation, and entertainment.
#
# Your goal is to:
#
# Calculate the total expense for the month by adding up all the amounts in the list.
# Print the total to see how much you’ve spent overall.
# The list expenses contains individual expense amounts for each category. By adding all these amounts together, you get the total amount spent for the month.
# Steps:
#
# Start with a list of expense amounts.
# Use a function to add all the values in the list.
# Print the final total expense for the month.
# Sample Output: Total Monthly Expense: 2850

# %%
#3.Calculate the total monthly expenses

#amount spent in each category
expenses = [2500, 1500, 1000, 500]
#calculating the sum
total_expense = sum(expenses)
#printing the total expense
print("Total Monthly Expense:", total_expense)
# Out:
# Total Monthly Expense: 5500

# %% [markdown]
# 4. Problem: Find the Highest Temperature of the Week
# Imagine you recorded the temperatures each day for a week and stored them in a tuple. Each value in the tuple represents the temperature for one day. Now, you want to find the highest temperature recorded during that week.
#
# In this problem, you need to:
#
# Store the weekly temperatures in a tuple (an unchangeable list of values).
# Use a method to find and print the highest temperature from this tuple.
# Key Points:
#
# A tuple is like a list but cannot be modified after it’s created.
# The max() function helps find the highest number in a collection, like our weekly temperatures.
# Steps:
#
# Create a tuple of temperatures, with each temperature representing one day.
# Use max() to find the highest temperature.
# Print the highest temperature to see the warmest day of the week.
# Sample Output: Highest Temperature of the Week: 80

# %%
#4.Problem: Find the Highest Temperature of the Week
#tuple of temp on 7 days of a week
temperatures = (34, 45, 56, 67, 78, 89, 90)
#finding highest temp
highest_temp = max(temperatures)
#printing highest temp
print("Highest Temperature of the Week:", highest_temp)
# Out:
# Highest Temperature of the Week: 90

# %% [markdown]
# 5. Problem: Identify the Position of an Item in a List
# Imagine you have a list of different fruits, and you want to find out where a specific fruit, "Orange", is located in this list. Each item in a list has a position (or index), which tells us where it appears in the order.
#
# In this problem, you need to:
#
# Start with a list of fruits.
# Use index("Orange") to find where "Orange" is located.
# Print the result, which shows the position of "Orange" in the list.
# Key Points:
#
# Lists are ordered, and each item has a specific index, starting from 0.
# The index() function helps find the position of a specific item in a list.
# Sample Output: Position of 'Orange': 2

# %%
#5.Identify the position of an item in a list
#fruits list
fruits = ["Apple", "Banana", "Orange", "Grapes", "Mango"]
#finding the position of orange
index_orange = fruits.index("Orange")
#printing the position of orange
print("Position of 'Orange':", index_orange)
# Out:
# Position of 'Orange': 2

# %% [markdown]
# 6. Problem: Sort List of Scores in Ascending Order
# Imagine you have a list of test scores from a recent exam, and you want to arrange these scores in ascending order (from the lowest to the highest score). Sorting the scores can help you see who performed the best and the worst in a clear, organized way.
#
# In this problem, you need to:
#
# Create a list of test scores.
# Use a method to sort the scores in ascending order.
# Print the sorted list to see the scores from lowest to highest.
# Key Points:
#
# When you sort a list in ascending order, the smallest score appears first, and the largest score appears last.
# The sort() function will change the order of elements in the list to arrange them from smallest to largest.
# Sample Output: Sorted Scores: [78, 85, 88, 90, 92]

# %%
#6. Sort list of Scores in Ascending Order
#list of test scores
test_scores = [88, 92, 78, 90, 85]
#sorting the list
test_scores.sort()
#printing the sorted list
print("Sorted Scores:", test_scores)
# Out:
# Sorted Scores: [78, 85, 88, 90, 92]

# %% [markdown]
# 7. Problem: Extract and Print a Subset of List Elements
# Imagine you have a list of book titles, and you want to show only the first three books from the list. You don't need to see the entire list, just the first three items.
#
# In this problem, you need to:
#
# Create a list of books.
# Extract the first three books from the list.
# Print this subset to see only the first three titles.
# Key Points:
#
# Lists allow you to select a portion of their elements using a technique called slicing.
# books[:3] means "select items starting from the beginning up to (but not including) index 3," which gives the first three items.
# Sample Output: First Three Books: ['1984', 'To Kill a Mockingbird', 'Pride and Prejudice']

# %%
#7. Extract and Print a Subset of List Elements
#list of books
books = ["1984", "To Kill a Mockingbird", "Pride and Prejudice", "The Great Gatsby"]
#slicing first 3 books and printing
print("First Three Books:", books[:3])
# Out:
# First Three Books: ['1984', 'To Kill a Mockingbird', 'Pride and Prejudice']

# %% [markdown]
# 8.Problem: Create a List of Even Numbers
# Imagine you want a list of even numbers between 1 and 10. Even numbers are numbers that can be divided by 2 with no remainder (like 2, 4, 6, etc.). Your goal is to create a list that includes only these even numbers within the specified range.
#
# In this problem, you need to:
#
# Initialize an empty list called even_numbers to store the even numbers.
# Use range(1, 11) to generate numbers from 1 to 10.
# Use a for loop to go through each number in this range.
# Use an if condition if i % 2 == 0 to check if a number is even.
# If the number is even, add it to the even_numbers list.
# Print the resulting list of even numbers.
# Key Points:
#
# Even numbers are numbers that can be divided by 2 without leaving a remainder (e.g., 2, 4, 6, 8).
# Start by initializing an empty list, and use a for loop and if condition to filter and add only even numbers to the list.
# Sample Output: Even Numbers from 1 to 10: [2, 4, 6, 8, 10]

# %%
#8.Create a List of Even Numbers
#an empty list of even numbers
even_numbers = []
#using range to generate 10 numbers
for i in range(1, 11):
    #checking if i is even or odd
    if i % 2 == 0:
        #adding even numbers to the list
        even_numbers.append(i)

#printing the even num list
print("Even Numbers from 1 to 10:", even_numbers)
# Out:
# Even Numbers from 1 to 10: [2, 4, 6, 8, 10]

# %% [markdown]
# 9. Problem: Check if an Item Exists in a Tuple
# Imagine you have a list of items typically found in an office, stored as a tuple (an unchangeable list). You want to check if a specific item, like a "Laptop", is included in this list. This is useful when you want to quickly confirm if an item is part of the group.
#
# In this problem, you need to:
#
# Start with creating a tuple containing office items.
# Use the in keyword to check if "Laptop" is present in the tuple.
# Print the result of this check.
# Key Points:
#
# Tuples are like lists but cannot be modified once created.
# The in keyword can check if an item exists within a tuple.
# Sample Output: Is 'Laptop' in the office items? True

# %%
#9.Check if an item exists in a tuple
#tuple containing office items
office_items = ("Pen", "Pencil", "Eraser", "Notebook", "Calculator", "Laptop")
#checking laptop in the list
for item in office_items:
    if item == "Laptop":
        print("Is 'Laptop' in the office items?", True)
        break
else:
    print("Is 'Laptop' in the office items?", False)
# Out:
# Is 'Laptop' in the office items? True

# %% [markdown]
# 10. Problem: Access an Element by Index
# Imagine you have a list of fruits stored as a tuple. Each fruit in the tuple is arranged in a specific order. You want to print the second fruit in this list. In Python, elements in tuples can be accessed by their index, which represents their position.
#
# In this problem, you need to:
#
# Create a tuple of fruits.
# Use indexing to access and print the fruit which is in the second fruit.
# Key Points:
#
# Tuples are ordered collections, and items in tuples are accessed using an index.
# The index 1 corresponds to the second item in the tuple.
# Sample Output: The second fruit is: Banana

# %%
#10.Access an Element by Index
#create a tuple of furits
fruits = ("Apple", "Banana", "Orange", "Grapes", "Mango")
#printing the second fruit
print("The second fruit is:", fruits[1])
# Out:
# The second fruit is: Banana

# %% [markdown]
# 11. Problem: Store Tuple Elements in Separate Variables
# Imagine you have a tuple that contains three details about a person: their name, age, and city. Instead of accessing each element by its position, you can directly store each of these details into separate variables. This makes it easier to work with the individual pieces of information.
#
# In this problem, you need to:
#
# Create a tuple with three elements: a name, an age, and a city.
# Store each element in the tuple into three different variables.
# Print each variable separately to display the person’s details.
# Key Points:
#
# Tuples allow you to store multiple values together.
# You can assign each value from the tuple to its own variable, which is useful for working with each piece of information independently.
# Sample Output:
#
# Name: Alice
#
# Age: 30
#
# City: New York

# %%
#11.Store tuple elements in Seperate variables
#tuple with name,age,city
person_details = ("Alice", 30, "New York")
#storing each ele in seperate vairable
name, age, city = person_details
#printing the variables
print("Name:", name)
print("Age:", age)
print("City:", city)
# Out:
# Name: Alice
# Age: 30
# City: New York

# %% [markdown]
# 12. Problem: Find Average of Tuple Elements
# Imagine you have a tuple containing the prices of several items. You want to find the average price of these items to get an idea of the typical cost. The average price is calculated by adding all the prices together and then dividing by the number of items.
#
# In this problem, you need to:
#
# Start with creating a tuple of item prices.
# Use sum() to find the total of all prices.
# Divide the total by the number of prices (len() of the tuple) to get the average.
# Print the average price.
# Key Points:
#
# The sum of the tuple’s elements gives the total of all prices.
# The len function finds the number of items in the tuple, which is used to calculate the average.
# Sample Output: Average Price: 250.0

# %%
#12.Find average of tuple elements
#tuple of item prices
item_prices = (100, 200, 300, 400, 500)
#finding the sum
total_price = sum(item_prices)
#finding the average
average_price = float(total_price / len(item_prices))
#printing the average
print("Average Price:", average_price)
# Out:
# Average Price: 300.0

# %% [markdown]
# 13. Problem: Find the Difference Between Max and Min Ages
# Imagine you have a tuple that contains the ages of different people. You want to find out the age difference between the oldest and youngest person. This difference is calculated by subtracting the smallest age from the largest age in the tuple.
#
# In this problem, you need to:
#
# Start with a tuple containing ages.
# Use max() to find the oldest age and min() to find the youngest age.
# Subtract the youngest age from the oldest age.
# Print the result to see the age difference.
# Key Points:
#
# The max() function finds the largest age in the tuple.
# The min() function finds the smallest age in the tuple.
# Subtracting these values gives the difference between the oldest and youngest ages.
# Sample Output: Age Difference: 20

# %%
#13.Find the difference between max and min ages
#tuple of ages
ages = (25, 30, 20, 34, 24)
#min and max ages
max_age = max(ages)
min_age = min(ages)
#printing the difference
print("Age Difference: ", max_age - min_age)
# Out:
# Age Difference:  14

# %% [markdown]
# 14. Problem: Multiply Tuple Elements
# Imagine you have a tuple that contains a few items, like "Pen" and "Notebook". Now, you want to create a new tuple where each item in the original tuple is repeated three times in sequence. This means if you start with a tuple of two items, repeating the tuple three times will give you six items in the final result, showing each original item three times in the same order.
#
# In this problem, you need to:
#
# Create a tuple of items.
# Multiply the tuple by 3, which will repeat the entire tuple three times in sequence.
# Print the result to see each item repeated three times.
# Key Points:
#
# Multiplying a tuple by a number (e.g., * 3) repeats all elements in the tuple that number of times.
# The order of items remains the same in each repetition.
# Sample Output: Repeated Items: ('Pen', 'Notebook', 'Pen', 'Notebook', 'Pen', 'Notebook')

# %%
#14. Multiply tuple elements REPETITION
#tuple of vowels
vowels = ("a", "e", "i", "o", "u")
#multiply tuple by 3
repeated_vowels = vowels * 3
#printing the repeated tuple
print("Repeated Items:", repeated_vowels)
# Out:
# Repeated Items: ('a', 'e', 'i', 'o', 'u', 'a', 'e', 'i', 'o', 'u', 'a', 'e', 'i', 'o', 'u')

# %% [markdown]
# 15. Problem: Merge Two Lists of Friends
# Imagine you have two separate lists of friends. One list includes a few friends you’ve known for a while, and the other list has some new friends you recently met. You want to combine these two lists into one so that you have all your friends in a single list.
#
# In this problem, you need to:
#
# Start with two lists of friends.
# Combine (or merge) these lists into one list that includes everyone from both lists.
# Print the final list to see all the friends together.
# Key Points:
#
# The + operator allows you to join two lists into a single list.
# The order of the lists will be preserved, so the friends in the first list will appear before the friends in the second list.
# Sample Output: All Friends: ['Tom', 'Jerry', 'Mickey', 'Minnie']

# %%
#15.  merge two lists of friends CONCATINATION
# two lists of friends
friends1 = ["Tom", "Jerry", "Mickey"]
friends2 = ["Minnie", "Donald", "Daisy"]
#merging the lists
print("All Friends: ", friends1 + friends2)
# Out:
# All Friends:  ['Tom', 'Jerry', 'Mickey', 'Minnie', 'Donald', 'Daisy']
